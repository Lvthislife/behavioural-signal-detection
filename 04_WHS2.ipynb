# %% [markdown]
# # 📊 WHS NLP Capstone – Notebook 4: Final Comparison, Dashboards & Persona Storytelling
# This notebook:
# - Compares performance across TF-IDF and RoBERTa models
# - Plots dashboard-style visual summaries
# - Explores results by persona (storytelling + behavioral inference)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Manual comparison table for quick reference
performance_data = pd.DataFrame({
    'Model': ['TF-IDF + Logistic', 'RoBERTa + Logistic'],
    'Action Quality F1': [0.81, 0.89],
    'Effort F1': [0.79, 0.87],
    'Psych Safety F1': [0.76, 0.85]
})
performance_data.set_index('Model', inplace=True)
performance_data.plot(kind='bar', figsize=(10, 5), title='F1 Scores by Model and Target', rot=0)
plt.ylabel('F1 Score')
plt.ylim(0.7, 1.0)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Assuming df['persona'], prob columns from Notebook 3
persona_summary = df.groupby('persona')[['prob_good_action']].mean().sort_values(by='prob_good_action')
sns.barplot(x=persona_summary['prob_good_action'], y=persona_summary.index)
plt.title('Avg. Probability of Good Action by Persona')
plt.xlabel('Probability')
plt.show()

# %% [markdown]
# ## 🧠 Persona-Level Insight and Storytelling
# - **Jackie (Conscientious)** tends to write detailed, proactive reports. Models consistently rate her actions as high quality.
# - **Billie (By-the-book)** tends to use formal, templated language. Sometimes flagged for lack of detail but never underperforms.
# - **Mick (Minimiser)** often under-assesses severity and uses vague language. High model risk.
# - **Damo (Disengaged)** shows signs of laziness and emotional distance. Predicted to submit lowest quality actions.
# - **Ari (Anxious)** uses tentative language, often signalling fear or avoidance. Reports vary in depth, but models pick up on psychological risk.

# %%
# Persona-wise distribution of effort and safety
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.boxplot(data=df, x='persona', y='effort_encoded', ax=axes[0])
axes[0].set_title('Effort Distribution by Persona')
axes[0].set_ylabel('Effort Score')
axes[0].tick_params(axis='x', rotation=45)

sns.boxplot(data=df, x='persona', y='psych_safety_encoded', ax=axes[1])
axes[1].set_title('Psych Safety Distribution by Persona')
axes[1].set_ylabel('Safety Score')
axes[1].tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()
